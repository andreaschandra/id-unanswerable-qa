# %% [markdown]
# # IDK MRC
# run_qa.py

# %%
# !pip install -qqq transformers simpletransformers nltk stanza
# Out:
#      |████████████████████████████████| 5.8 MB 15.2 MB/s
#      |████████████████████████████████| 250 kB 78.2 MB/s
#      |████████████████████████████████| 691 kB 72.5 MB/s
#      |████████████████████████████████| 7.6 MB 64.7 MB/s
#      |████████████████████████████████| 182 kB 67.1 MB/s
#      |████████████████████████████████| 1.3 MB 59.5 MB/s
#      |████████████████████████████████| 9.2 MB 68.7 MB/s
#      |████████████████████████████████| 452 kB 70.7 MB/s
#      |████████████████████████████████| 43 kB 2.0 MB/s
#      |████████████████████████████████| 1.9 MB 60.9 MB/s
#      |████████████████████████████████| 182 kB 75.6 MB/s
#      |████████████████████████████████| 174 kB 76.5 MB/s
#      |████████████████████████████████| 62 kB 1.7 MB/s
#      |████████████████████████████████| 173 kB 77.3 MB/s
#      |████████████████████████████████| 168 kB 81.8 MB/s
#      |████████████████████████████████| 168 kB 87.0 MB/s
#      |████████████████████████████████| 166 kB 81.7 MB/s
#      |████████████████████████████████| 166 kB 86.4 MB/s
#      |████████████████████████████████| 162 kB 78.3 MB/s
#      |████████████████████████████████| 162 kB 76.3 MB/s
#      |████████████████████████████████| 158 kB 86.9 MB/s
#      |████████████████████████████████| 157 kB 83.9 MB/s
#      |████████████████████████████████| 157 kB 69.3 MB/s
#      |████████████████████████████████| 157 kB 83.2 MB/s
#      |████████████████████████████████| 157 kB 85.0 MB/s
#      |████████████████████████████████| 157 kB 83.6 MB/s
#      |████████████████████████████████| 157 kB 85.5 MB/s
#      |████████████████████████████████| 157 kB 62.8 MB/s
#      |████████████████████████████████| 156 kB 86.2 MB/s
#      |████████████████████████████████| 240 kB 83.4 MB/s
#      |████████████████████████████████| 212 kB 77.4 MB/s
#      |████████████████████████████████| 132 kB 67.5 MB/s
#      |████████████████████████████████| 127 kB 58.4 MB/s
#      |████████████████████████████████| 78 kB 8.7 MB/s
#      |████████████████████████████████| 4.7 MB 67.2 MB/s
#      |████████████████████████████████| 164 kB 81.1 MB/s
#      |████████████████████████████████| 237 kB 82.7 MB/s
#      |████████████████████████████████| 51 kB 8.4 MB/s
#   Building wheel for emoji (setup.py) ... done
#   Building wheel for pathtools (setup.py) ... done
#   Building wheel for seqeval (setup.py) ... done
#   Building wheel for validators (setup.py) ... done

# %%
# !cp -r /content/drive/MyDrive/IDK-MRC/dataset .

# %%
import argparse
import json
import os
import torch
import wandb
from transformers.utils import logging
from simpletransformers.question_answering import QuestionAnsweringModel
from squad_2_0_eval import evaluate, compute_f1

# %%
wandb.login()
# Out:
# ERROR:wandb.jupyter:Failed to detect the name of this notebook, you can set it manually with the WANDB_NOTEBOOK_NAME environment variable to enable code saving.
# wandb: Logging into wandb.ai. (Learn how to deploy a W&B server locally: https://wandb.me/wandb-server)
# wandb: You can find your API key in your browser here: https://wandb.ai/authorize
# wandb: Paste an API key from your profile and hit enter, or press ctrl+c to quit:
# ··········
# wandb: Appending key for api.wandb.ai to your netrc file: /root/.netrc
# True

# %%
torch.multiprocessing.set_sharing_strategy('file_system')
logger = logging.get_logger(__name__)

# %%
def get_model(args, train_args, pretrained=None):
    if 'indobert' in args.pretrain_name:
        train_args['config'] = {
            'num_labels': 2,
            'id2label': {
                "0": "LABEL_0",
                "1": "LABEL_1"
            },
            'label2id': {
                "LABEL_0": 0,
                "LABEL_1": 1
            }
        }

    if pretrained is None:
        pretrained = args.pretrain_name

    # use first available gpu
    cuda_device = -1 if 'n_gpu' in train_args and train_args['n_gpu'] > 1 else args.device_num

    return QuestionAnsweringModel(args.model_name, pretrained, args=train_args, cuda_device=cuda_device, use_cuda=torch.cuda.is_available())

# %%
def eval_qa(model, val_path, eval_output_dir, filename='eval_result'):
    if not os.path.exists(eval_output_dir):
        os.makedirs(eval_output_dir)

    result, text = model.eval_model(val_path, output_dir=eval_output_dir)
    exact_match, f1, result_squad = evaluate(val_path, eval_output_dir + 'predictions_test.json')
    result['exact'] = exact_match
    result['f1'] = f1

    # Save result
    with open(eval_output_dir + filename + '.json', 'w') as f:
        json.dump(result, f)

    with open(eval_output_dir + filename + '_text.json', 'w') as f:
        json.dump(text, f)

    with open(eval_output_dir + filename + '_squad_2.0.json', 'w') as f:
        json.dump(result_squad, f)

    return result, text, result_squad

# %%
def hasans_f1_metric(true_answers, predicted_answers):
    f1_scores = []
    for true_ans, pred_ans in zip(true_answers, predicted_answers):
        if len(true_ans) > 0:
            f1 = compute_f1(true_ans, pred_ans)
            f1_scores.append(f1)
    return 100.0 * sum(f1_scores) / len(f1_scores)

# %%
def avg_f1_metric(true_answers, predicted_answers):
    ans_f1_scores, unans_f1_scores = [], []
    for true_ans, pred_ans in zip(true_answers, predicted_answers):
        f1 = compute_f1(true_ans, pred_ans)
        if len(true_ans) > 0:
            ans_f1_scores.append(f1)
        else:
            unans_f1_scores.append(f1)
    ans_f1 = 100.0 * sum(ans_f1_scores) / len(ans_f1_scores)
    unans_f1 = 100.0 * sum(unans_f1_scores) / len(unans_f1_scores)
    return (ans_f1 + unans_f1) / 2

# %%
def train_qa(args, train_args, train_path, eval_path):
    
    print("WandB initialize...")
    wandb.init(project=args.wb_name)
    wandb.run.name = args.out_name
    wandb.run.save()
    
    print("Get model...")
    model = get_model(args, train_args)
    
    print("train_model()")
    model.train_model(train_path, eval_data=eval_path, ans_f1=hasans_f1_metric)

# %%
args = argparse.Namespace(
    train_path="dataset/idk_mrc/train.json",
    val_path="dataset/idk_mrc/valid.json",
    test_path="dataset/idk_mrc/test.json",
    model_name="xlmroberta",
    pretrain_name="xlm-roberta-base",
    epoch=10,
    device_num=0,
    n_gpu=1,
    wb_name="idk-mrc",
    wb_name_test="idk-mrc-test",
    out_path="outputs",
    out_name="indobert_squad",
    lang="id",
    seed=42,
    uncased=True,
    only_test=False
)

# %%
print("Running model for seed:", str(args.seed))
print("Input file:", args.train_path)
# Out:
# Running model for seed: 42
# Input file: dataset/idk_mrc/train.json

# %%
output_dir = args.out_path + '/' + args.wb_name + '/' + args.model_name + '/' + args.out_name + '/' + str(args.seed) + '/'
train_args = {
    'learning_rate': 2e-5,
    'num_train_epochs': args.epoch,
    'max_seq_length': 512,
    'max_query_length': 128,
    'doc_stride': 128,
    'overwrite_output_dir': True,
    'reprocess_input_data': True,
    'train_batch_size': 16,
    'fp16': True,
    'output_dir': output_dir,
    'wandb_project': args.wb_name,
    'n_best_size': 20,
    'manual_seed': args.seed,
    'encoding': 'utf-8',
    'save_eval_checkpoints': False,
    'save_model_every_epoch': False,
    'save_steps': -1,
    'do_lower_case': args.uncased,
    'adam_epsilon': 1e-8,
    'n_gpu': args.n_gpu,
    'best_model_dir': output_dir + 'best_model/',
    'evaluate_during_training': True,
    'evaluate_during_training_steps': 2000,
    'early_stopping_metric': 'ans_f1',
    'early_stopping_metric_minimize': False,
    'no_cache': True
}

# %% [markdown]
# # Train the model

# %%
if not args.only_test:
    print("Start training...")
    train_qa(args, train_args, args.train_path, args.val_path)
else:
    wandb.init(project=args.wb_name_test)
    wandb.run.name = args.out_name
    wandb.run.save()
# Out:
# wandb: Currently logged in as: andreaschandra. Use `wandb login --relogin` to force relogin
# Start training...
# WandB initialize...
# Tracking run with wandb version 0.13.7
# Run data is saved locally in <code>/content/wandb/run-20221222_114159-19zexbfb</code>
# Syncing run <strong><a href="https://wandb.ai/andreaschandra/idk-mrc/runs/19zexbfb" target="_blank">magic-star-14</a></strong> to <a href="https://wandb.ai/andreaschandra/idk-mrc" target="_blank">Weights & Biases</a> (<a href="https://wandb.me/run" target="_blank">docs</a>)<br/>
# wandb: WARNING Calling wandb.run.save without any arguments is deprecated.Changes to attributes are automatically persisted.
# Get model...
# Downloading:   0%|          | 0.00/615 [00:00<?, ?B/s]
# Downloading:   0%|          | 0.00/1.12G [00:00<?, ?B/s]
# Some weights of the model checkpoint at xlm-roberta-base were not used when initializing XLMRobertaForQuestionAnswering: ['lm_head.layer_norm.weight', 'lm_head.dense.weight', 'lm_head.bias', 'lm_head.dense.bias', 'lm_head.layer_norm.bias', 'lm_head.decoder.weight']
# - This IS expected if you are initializing XLMRobertaForQuestionAnswering from the checkpoint of a model trained on another task or with another architecture (e.g. initializing a BertForSequenceClassification model from a BertForPreTraining model).
# - This IS NOT expected if you are initializing XLMRobertaForQuestionAnswering from the checkpoint of a model that you expect to be exactly identical (initializing a BertForSequenceClassification model from a BertForSequenceClassification model).
# Some weights of XLMRobertaForQuestionAnswering were not initialized from the model checkpoint at xlm-roberta-base and are newly initialized: ['qa_outputs.bias', 'qa_outputs.weight']
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.
# Downloading:   0%|          | 0.00/5.07M [00:00<?, ?B/s]
# train_model()
# convert squad examples to features:   0%|          | 1/9332 [00:17<45:48:52, 17.68s/it]Could not find answer: 'tahun 936 sampai kematiannya pada sekitar tahun 958.[3]' vs. '936 sampai kematiannya pada sekitar tahun 958'
# Could not find answer: 'Desember 2011.' vs. '6 Desember 2011'
# convert squad examples to features: 100%|██████████| 9332/9332 [00:32<00:00, 288.90it/s]
# add example index and unique id: 100%|██████████| 9332/9332 [00:00<00:00, 753716.37it/s]
# Epoch:   0%|          | 0/10 [00:00<?, ?it/s]
# Finishing last run (ID:19zexbfb) before initializing another...
# Waiting for W&B process to finish... <strong style="color:green">(success).</strong>
# Synced <strong style="color:#cdcd00">magic-star-14</strong>: <a href="https://wandb.ai/andreaschandra/idk-mrc/runs/19zexbfb" target="_blank">https://wandb.ai/andreaschandra/idk-mrc/runs/19zexbfb</a><br/>Synced 5 W&B file(s), 0 media file(s), 0 artifact file(s) and 0 other file(s)
# Find logs at: <code>./wandb/run-20221222_114159-19zexbfb/logs</code>
# Successfully finished last run (ID:19zexbfb). Initializing new run:<br/>
# Tracking run with wandb version 0.13.7
# Run data is saved locally in <code>/content/wandb/run-20221222_114314-j94i3l5t</code>
# Syncing run <strong><a href="https://wandb.ai/andreaschandra/idk-mrc/runs/j94i3l5t" target="_blank">jumping-forest-15</a></strong> to <a href="https://wandb.ai/andreaschandra/idk-mrc" target="_blank">Weights & Biases</a> (<a href="https://wandb.me/run" target="_blank">docs</a>)<br/>
# Running Epoch 0 of 10:   0%|          | 0/594 [00:00<?, ?it/s]
# /usr/local/lib/python3.8/dist-packages/torch/optim/lr_scheduler.py:138: UserWarning: Detected call of `lr_scheduler.step()` before `optimizer.step()`. In PyTorch 1.1.0 and later, you should call them in the opposite order: `optimizer.step()` before `lr_scheduler.step()`.  Failure to do this will result in PyTorch skipping the first value of the learning rate schedule. See more details at https://pytorch.org/docs/stable/optim.html#how-to-adjust-learning-rate
#   warnings.warn("Detected call of `lr_scheduler.step()` before `optimizer.step()`. "
#
# convert squad examples to features:   0%|          | 0/764 [00:00<?, ?it/s]
# convert squad examples to features:   0%|          | 1/764 [00:01<18:35,  1.46s/it]
# convert squad examples to features: 100%|██████████| 764/764 [00:02<00:00, 345.93it/s]
#
# add example index and unique id: 100%|██████████| 764/764 [00:00<00:00, 247333.15it/s]
# Running Evaluation:   0%|          | 0/96 [00:00<?, ?it/s]
# Running Epoch 1 of 10:   0%|          | 0/594 [00:00<?, ?it/s]
# convert squad examples to features:   0%|          | 0/764 [00:00<?, ?it/s]
# convert squad examples to features:   0%|          | 1/764 [00:01<18:18,  1.44s/it]
# convert squad examples to features: 100%|██████████| 764/764 [00:02<00:00, 351.36it/s]
#
# add example index and unique id: 100%|██████████| 764/764 [00:00<00:00, 214315.69it/s]
# Running Evaluation:   0%|          | 0/96 [00:00<?, ?it/s]
# Running Epoch 2 of 10:   0%|          | 0/594 [00:00<?, ?it/s]
# convert squad examples to features:   0%|          | 0/764 [00:00<?, ?it/s]
# convert squad examples to features:   0%|          | 1/764 [00:01<19:05,  1.50s/it]
# convert squad examples to features: 100%|██████████| 764/764 [00:02<00:00, 343.48it/s]
#
# add example index and unique id: 100%|██████████| 764/764 [00:00<00:00, 476852.42it/s]
# Running Evaluation:   0%|          | 0/96 [00:00<?, ?it/s]
# Running Epoch 3 of 10:   0%|          | 0/594 [00:00<?, ?it/s]
# convert squad examples to features:   0%|          | 0/764 [00:00<?, ?it/s]
#
# convert squad examples to features:   0%|          | 1/764 [00:01<18:50,  1.48s/it]
#
# convert squad examples to features: 100%|██████████| 764/764 [00:02<00:00, 343.70it/s]
#
#
# add example index and unique id: 100%|██████████| 764/764 [00:00<00:00, 621017.10it/s]
# Running Evaluation:   0%|          | 0/96 [00:00<?, ?it/s]
# convert squad examples to features:   0%|          | 0/764 [00:00<?, ?it/s]
# convert squad examples to features:   0%|          | 1/764 [00:01<19:21,  1.52s/it]
# convert squad examples to features: 100%|██████████| 764/764 [00:02<00:00, 333.65it/s]
#
# add example index and unique id: 100%|██████████| 764/764 [00:00<00:00, 489827.00it/s]
# Running Evaluation:   0%|          | 0/96 [00:00<?, ?it/s]
# Running Epoch 4 of 10:   0%|          | 0/594 [00:00<?, ?it/s]
# convert squad examples to features:   0%|          | 0/764 [00:00<?, ?it/s]
# convert squad examples to features:   0%|          | 1/764 [00:01<19:34,  1.54s/it]
# convert squad examples to features: 100%|██████████| 764/764 [00:02<00:00, 337.97it/s]
#
# add example index and unique id: 100%|██████████| 764/764 [00:00<00:00, 463807.82it/s]
# Running Evaluation:   0%|          | 0/96 [00:00<?, ?it/s]
# Running Epoch 5 of 10:   0%|          | 0/594 [00:00<?, ?it/s]
# convert squad examples to features:   0%|          | 0/764 [00:00<?, ?it/s]
# convert squad examples to features:   0%|          | 1/764 [00:01<18:24,  1.45s/it]
# convert squad examples to features: 100%|██████████| 764/764 [00:02<00:00, 350.81it/s]
#
# add example index and unique id: 100%|██████████| 764/764 [00:00<00:00, 455436.08it/s]
# Running Evaluation:   0%|          | 0/96 [00:00<?, ?it/s]
# Running Epoch 6 of 10:   0%|          | 0/594 [00:00<?, ?it/s]
# convert squad examples to features:   0%|          | 0/764 [00:00<?, ?it/s]
#
# convert squad examples to features:   0%|          | 1/764 [00:01<18:39,  1.47s/it]
#
# convert squad examples to features: 100%|██████████| 764/764 [00:02<00:00, 348.40it/s]
#
#
# add example index and unique id: 100%|██████████| 764/764 [00:00<00:00, 373653.01it/s]
# Running Evaluation:   0%|          | 0/96 [00:00<?, ?it/s]
# convert squad examples to features:   0%|          | 0/764 [00:00<?, ?it/s]
# convert squad examples to features:   0%|          | 1/764 [00:01<19:00,  1.49s/it]
# convert squad examples to features: 100%|██████████| 764/764 [00:02<00:00, 346.57it/s]
#
# add example index and unique id: 100%|██████████| 764/764 [00:00<00:00, 484568.01it/s]
# Running Evaluation:   0%|          | 0/96 [00:00<?, ?it/s]
# Running Epoch 7 of 10:   0%|          | 0/594 [00:00<?, ?it/s]
# convert squad examples to features:   0%|          | 0/764 [00:00<?, ?it/s]
# convert squad examples to features:   0%|          | 1/764 [00:01<18:50,  1.48s/it]
# convert squad examples to features: 100%|██████████| 764/764 [00:02<00:00, 339.62it/s]
#
# add example index and unique id: 100%|██████████| 764/764 [00:00<00:00, 501792.71it/s]
# Running Evaluation:   0%|          | 0/96 [00:00<?, ?it/s]
# Running Epoch 8 of 10:   0%|          | 0/594 [00:00<?, ?it/s]
# convert squad examples to features:   0%|          | 0/764 [00:00<?, ?it/s]
# convert squad examples to features:   0%|          | 1/764 [00:02<26:39,  2.10s/it]
# convert squad examples to features: 100%|██████████| 764/764 [00:02<00:00, 287.98it/s]
#
# add example index and unique id: 100%|██████████| 764/764 [00:00<00:00, 364431.74it/s]
# Running Evaluation:   0%|          | 0/96 [00:00<?, ?it/s]
# Running Epoch 9 of 10:   0%|          | 0/594 [00:00<?, ?it/s]
# convert squad examples to features:   0%|          | 0/764 [00:00<?, ?it/s]
# convert squad examples to features:   0%|          | 1/764 [00:01<18:22,  1.45s/it]
# convert squad examples to features: 100%|██████████| 764/764 [00:02<00:00, 353.06it/s]
#
# add example index and unique id: 100%|██████████| 764/764 [00:00<00:00, 407379.64it/s]
# Running Evaluation:   0%|          | 0/96 [00:00<?, ?it/s]

# %% [markdown]
# # Evaluate the model

# %%
model = get_model(args, train_args, pretrained=output_dir + 'best_model/')

# %%
_, _, result_squad = eval_qa(model, args.test_path, output_dir + 'test/')
wandb.log({
    'HasAns_exact': result_squad['HasAns_exact'],
    'HasAns_f1': result_squad['HasAns_f1'],
    'NoAns_exact': result_squad['NoAns_exact'] if 'NoAns_exact' in result_squad else 0,
    'NoAns_f1': result_squad['NoAns_f1'] if 'NoAns_f1' in result_squad else 0,
    'exact': result_squad['exact'],
    'f1': result_squad['f1']
})
# Out:
# convert squad examples to features: 100%|██████████| 844/844 [00:02<00:00, 333.51it/s]
# add example index and unique id: 100%|██████████| 844/844 [00:00<00:00, 266325.05it/s]
# Running Evaluation:   0%|          | 0/107 [00:00<?, ?it/s]

# %%
result_squad
# Out:
# OrderedDict([('exact', 74.28909952606635),
#              ('f1', 81.34571191001065),
#              ('total', 844),
#              ('HasAns_exact', 59.241706161137444),
#              ('HasAns_f1', 73.35493092902607),
#              ('HasAns_total', 422),
#              ('NoAns_exact', 89.33649289099526),
#              ('NoAns_f1', 89.33649289099526),
#              ('NoAns_total', 422)])
